# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Sergio Onita, I'm a student working on practices for a financial company.**

# %% [markdown]
# *I am interested in Data Science because it allows you to understand and obtain conclusions from ordinary data, which is pretty cool because it allows you to do amazing things. I started by watching videos from Dataiku on youtube.*

# %% [markdown]
# ### The following code should just print Hello World

# %%
print('Hello World')
# Out:
# Hello World

# %% [markdown]
# This is the first line, which will be separated by a horizontal rule.
# <hr>
# <a href="https://www.youtube.com/watch?v=Yr8O3tWRiY8"> Link to a youtube video im just gonna watch </a>
#
# ~~strikethrough~~
